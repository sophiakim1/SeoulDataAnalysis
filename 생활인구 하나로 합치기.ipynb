# %%
import numpy as np
import pandas as pd
import seaborn as sns
from google.colab import drive
import matplotlib.pyplot as plt

# %%
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df_people_2101 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/팀과제/LOCAL_PEOPLE_DONG_202101.csv', encoding='cp949') 
df_people_2102 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/팀과제/LOCAL_PEOPLE_DONG_202102.csv', encoding='cp949') 
df_people_2103 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/팀과제/LOCAL_PEOPLE_DONG_202103.csv', encoding='cp949') 
df_people_2104 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/팀과제/LOCAL_PEOPLE_DONG_202104.csv', encoding='cp949') 
df_people_2105 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/팀과제/LOCAL_PEOPLE_DONG_202105.csv', encoding='cp949') 
df_people_2106 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/팀과제/LOCAL_PEOPLE_DONG_202106.csv', encoding='cp949') 
df_people_2107 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/팀과제/LOCAL_PEOPLE_DONG_202107.csv', encoding='cp949')

# %%
df_people_2108 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/팀과제/LOCAL_PEOPLE_DONG_202108.csv',index_col=False)

# %%
df_people_2109 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/팀과제/LOCAL_PEOPLE_DONG_202109.csv',index_col=False) 
df_people_2110 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/팀과제/LOCAL_PEOPLE_DONG_202110.csv',index_col=False) 
df_people_2111 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/팀과제/LOCAL_PEOPLE_DONG_202111.csv',index_col=False) 
df_people_2112 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/팀과제/LOCAL_PEOPLE_DONG_202112.csv',index_col=False)

# %%
df_people_2201 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/팀과제/LOCAL_PEOPLE_DONG_202201.csv', encoding='cp949') 
df_people_2202 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/팀과제/LOCAL_PEOPLE_DONG_202202.csv',index_col=False) 
df_people_2203 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/팀과제/LOCAL_PEOPLE_DONG_202203.csv',index_col=False) 
df_people_2204 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/팀과제/LOCAL_PEOPLE_DONG_202204.csv',index_col=False) 
df_people_2205 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/팀과제/LOCAL_PEOPLE_DONG_202205.csv',index_col=False) 
df_people_2206 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/팀과제/LOCAL_PEOPLE_DONG_202206.csv',index_col=False)

# %%
df_people_2207 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/팀과제/LOCAL_PEOPLE_DONG_202207.csv', encoding='cp949') 
df_people_2208 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/팀과제/LOCAL_PEOPLE_DONG_202208.csv',index_col=False) 
df_people_2209 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/팀과제/LOCAL_PEOPLE_DONG_202209.csv',index_col=False) 
df_people_2210 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/팀과제/LOCAL_PEOPLE_DONG_202210.csv',index_col=False) 
df_people_2211 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/팀과제/LOCAL_PEOPLE_DONG_202211.csv',index_col=False) 
df_people_2212 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/팀과제/LOCAL_PEOPLE_DONG_202212.csv',index_col=False)

# %%
df_people = pd.concat([df_people_2101, df_people_2102, df_people_2103,df_people_2104, df_people_2105,df_people_2106,df_people_2107,df_people_2108,df_people_2109,df_people_2110,df_people_2111,df_people_2112,df_people_2201, df_people_2202, df_people_2203,df_people_2204, df_people_2205,df_people_2206,df_people_2207,df_people_2208,df_people_2209,df_people_2210,df_people_2211,df_people_2212 ],sort=False)

# %%
df_people.describe()
# Out:
#               기준일ID         시간대구분         행정동코드        총생활인구수  남자0세부터9세생활인구수  \
# count  7.428480e+06  7.428480e+06  7.428480e+06  7.428480e+06   7.428480e+06
# mean   2.021567e+07  1.150000e+01  1.143320e+07  2.433659e+04   8.393468e+02
# std    5.011889e+03  6.922187e+00  1.916679e+05  1.343475e+04   5.682324e+02
# min    2.021010e+07  0.000000e+00  1.111052e+07  1.102867e+03   0.000000e+00
# 25%    2.021070e+07  5.750000e+00  1.126065e+07  1.581637e+04   4.710186e+02
# 50%    2.021567e+07  1.150000e+01  1.144062e+07  2.161105e+04   7.086048e+02
# 75%    2.022070e+07  1.725000e+01  1.159814e+07  3.005565e+04   1.068008e+03
# max    2.022123e+07  2.300000e+01  1.174070e+07  3.448004e+05   1.898909e+04
#
#        남자10세부터14세생활인구수  남자15세부터19세생활인구수  남자20세부터24세생활인구수  남자25세부터29세생활인구수  \
# count     7.428480e+06     7.428480e+06     7.428480e+06     7.428480e+06
# mean      4.506194e+02     6.295803e+02     7.437553e+02     9.607530e+02
# ...

# %%
# reset_index(drop=True)
df_people.reset_index(drop=True)
# Out:
#             기준일ID  시간대구분     행정동코드      총생활인구수  남자0세부터9세생활인구수  \
# 0        20210101      0  11110515  14473.8890       504.7535
# 1        20210101      0  11110530  13299.5313       364.9421
# 2        20210101      0  11110550  15518.3772       418.3329
# 3        20210101      0  11110600   5108.9481       122.7939
# 4        20210101      0  11110700   7907.7246       224.1087
# ...           ...    ...       ...         ...            ...
# 7428475  20221231     23  11740550  26849.5654      2351.0068
# 7428476  20221231     23  11590540  20025.0040      1031.9551
# 7428477  20221231     23  11470630  16125.0930       526.2720
# 7428478  20221231     23  11710540  14964.0371       658.0712
# 7428479  20221231     23  11410520  15880.9395       531.5645
#
#          남자10세부터14세생활인구수  남자15세부터19세생활인구수  남자20세부터24세생활인구수  남자25세부터29세생활인구수  \
# 0               321.6298         474.2765         624.4867         507.3616
# ...

# %%
df_people.to_csv('./df_people.csv',encoding ='utf-8')

# %%
df_people.describe()

# %%
df_people.info()

# %%
# df['DOB']=pd.to_datetime(df['DOB'].astype(str), format='%m/%d/%Y')
